# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Student_performance_data.csv')
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           3
# dtype: int64

# %%
handle = df['GradeClass'].median()
handle
# Out:
# 4.0

# %%
df.GradeClass= df.GradeClass.fillna(handle)
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df['GradeClass'].value_counts()
# Out:
# GradeClass
# 4.0    1213
# 3.0     414
# 2.0     390
# 1.0     268
# 0.0     107
# Name: count, dtype: int64

# %%
x=df[['Absences']]
x
# Out:
#       Absences
# 0            7
# 1            0
# 2           26
# 3           14
# 4           17
# ...        ...
# 2387         2
# 2388         4
# 2389        20
# 2390        17
# 2391        13
#
# [2392 rows x 1 columns]

# %%
y = df[['GradeClass']]
y
# Out:
#       GradeClass
# 0            4.0
# 1            1.0
# 2            4.0
# 3            3.0
# 4            4.0
# ...          ...
# 2387         0.0
# 2388         4.0
# 2389         2.0
# 2390         1.0
# 2391         1.0
#
# [2392 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=15)
x_train
# Out:
#       Absences
# 1734        28
# 1631         4
# 1290        17
# 785         27
# 1476        13
# ...        ...
# 943         12
# 630          3
# 2133        20
# 1739        16
# 2204        27
#
# [1913 rows x 1 columns]

# %%
x_train
# Out:
#       Absences
# 1734        28
# 1631         4
# 1290        17
# 785         27
# 1476        13
# ...        ...
# 943         12
# 630          3
# 2133        20
# 1739        16
# 2204        27
#
# [1913 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=70)
x_train
# Out:
#       Absences
# 2066        25
# 440          2
# 2033        27
# 95          29
# 1764        21
# ...        ...
# 436          0
# 1083        22
# 1340        26
# 1138         8
# 214         11
#
# [1435 rows x 1 columns]

# %%
x_test
# Out:
#       Absences
# 2173        13
# 542          6
# 232         17
# 1855         2
# 1976         8
# ...        ...
# 1744         9
# 1297         1
# 486         15
# 329         10
# 675         25
#
# [957 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_train)
# Out:
# array([4., 1., 4., ..., 4., 2., 3.])

# %%
model.predict(x_test)
# Out:
# array([4., 2., 4., 2., 2., 3., 4., 2., 2., 4., 2., 3., 2., 3., 2., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 2., 4., 4., 4., 2., 2., 2., 3., 4.,
#        2., 4., 4., 2., 4., 4., 4., 4., 4., 4., 4., 4., 2., 3., 4., 4., 2.,
#        2., 4., 4., 4., 4., 4., 4., 2., 2., 4., 4., 4., 4., 4., 4., 2., 4.,
#        4., 2., 2., 3., 2., 2., 2., 2., 2., 4., 2., 4., 4., 4., 4., 3., 4.,
#        4., 4., 2., 2., 4., 4., 3., 4., 2., 4., 4., 4., 4., 2., 2., 2., 4.,
#        2., 4., 4., 4., 2., 2., 4., 3., 4., 2., 4., 4., 2., 4., 3., 3., 2.,
#        2., 2., 3., 4., 4., 2., 4., 2., 4., 3., 4., 4., 4., 2., 3., 3., 4.,
#        3., 4., 2., 2., 4., 3., 2., 4., 4., 2., 4., 2., 4., 4., 4., 2., 4.,
#        4., 4., 2., 4., 2., 4., 2., 4., 2., 4., 4., 2., 2., 2., 3., 4., 4.,
#        4., 4., 4., 4., 2., 4., 2., 4., 3., 4., 4., 2., 2., 4., 4., 2., 4.,
#        3., 2., 3., 2., 4., 4., 2., 4., 2., 2., 2., 2., 4., 4., 4., 4., 4.,
# ...

# %%
model.score(x_train,y_train)
# Out:
# 0.6550522648083623

# %%
model.score(x_test,y_test)
# Out:
# 0.6468129571577848
