# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("/dataset.xlsx")
df
# Out:
#    STUDENT ID      NAME  AGE  GENDER        PH NO      ADDRESS FATHER NAME  \
# 0         231   keerthi   20  female   6389065478      chennai        mani
# 1         232      viji   19  female   9579052268      chennai      ramesh
# 2         234    nithin   18    male   9765432889      madurai       kumar
# 3         235     aslin   21    male  96754321076       kerala      suresh
# 4         236  ghambhir   20    male  64589324678  pondicherry         ram
#
#   OCCUPATION BLOOD GRP  INCOME NATIONALITY
# 0   employee      A+ve  100000       india
# 1   employee     AB+ve  200000       india
# 2   employee      O+ve  300000       india
# 3     doctor     AB-ve  400000       india
# 4     doctor      B+ve  500000       india

# %%
df.head(3)
# Out:
#    STUDENT ID     NAME  AGE  GENDER       PH NO  ADDRESS FATHER NAME  \
# 0         231  keerthi   20  female  6389065478  chennai        mani
# 1         232     viji   19  female  9579052268  chennai      ramesh
# 2         234   nithin   18    male  9765432889  madurai       kumar
#
#   OCCUPATION BLOOD GRP  INCOME NATIONALITY
# 0   employee      A+ve  100000       india
# 1   employee     AB+ve  200000       india
# 2   employee      O+ve  300000       india

# %%
df.tail(2)
# Out:
#    STUDENT ID      NAME  AGE GENDER        PH NO      ADDRESS FATHER NAME  \
# 3         235     aslin   21   male  96754321076       kerala      suresh
# 4         236  ghambhir   20   male  64589324678  pondicherry         ram
#
#   OCCUPATION BLOOD GRP  INCOME NATIONALITY
# 3     doctor     AB-ve  400000       india
# 4     doctor      B+ve  500000       india

# %%
plt.figure(figsize=(13,7))
plt.plot(df['STUDENT ID'],df['AGE'])
plt.show()
